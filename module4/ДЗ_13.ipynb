# %% [markdown]
# <a href="https://colab.research.google.com/github/VDidyk/AI/blob/master/module4/%D0%94%D0%97_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів

# %%
import pandas as pd

# %% [markdown]
# Дані про банани

# %%
# трохи обробки даних
df = pd.read_csv('https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/banana_quality.csv')

df['Quality'] = df['Quality'].map({'Good': 1, 'Bad': 0})

columns = df.columns.delete(-1)
data = df[columns]
df[columns] = (data - data.min()) / (data.max() - data.min())

# %%
df.head()
# Out:
#        Size    Weight  Sweetness  Softness  HarvestTime  Ripeness   Acidity  \
# 0  0.380309  0.626747   0.680712  0.360975     0.567312  0.671933  0.543416
# 1  0.349951  0.628093   0.485275  0.293682     0.481689  0.646850  0.545720
# 2  0.478460  0.699448   0.572694  0.283811     0.499358  0.716580  0.617337
# 3  0.446465  0.705394   0.595677  0.374028     0.473461  0.633590  0.556625
# 4  0.541672  0.687704   0.458841  0.378242     0.442847  0.579430  0.705908
#
#    Quality
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# Потрібно на основі інформації про банан спрогнозувати його якість `Quality`

# %% [markdown]
# # Завдання 1
# Створіть клас Dataset для тренувальних та тестових даних

# %%
import torch
import pandas as pd

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %%
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

class MyDataset(Dataset):
    def __init__(self, X, y):
      self.X = torch.FloatTensor(X.values)
      self.y = torch.FloatTensor(y.values)
      self.y = self.y.reshape(-1, 1)

    def __len__(self):
      return len(self.X)

    def __getitem__(self, idx):
      return self.X[idx], self.y[idx]

# Create dataset object
X = df.drop(columns=['Quality'])
y = df['Quality']

dataset = MyDataset(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.8,
                                                    random_state=42,
                                                    stratify=y
                                                    )

dataset_train = MyDataset(X_train, y_train)
dataset_test = MyDataset(X_test, y_test)

# %%
y_train[y_train == 0].count()
# Out:
# 3195

# %%
y_train[y_train == 1].count()
# Out:
# 3205

# %% [markdown]
# # Завдання 2
# Створіть DataLoader

# %%
from torch.utils.data import DataLoader

batch_size = 256
train_dl = DataLoader(dataset_train,
                      batch_size=batch_size,
                      shuffle=True
                      )

test_dl = DataLoader(dataset_test,
                     batch_size=batch_size,
                     shuffle=True
                     )

# %% [markdown]
# # Завдання 3
# Створіть нейромережу

# %%
import numpy as np
from torch import nn
import torch.nn.functional as F


class BinaryClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()

        self.linear1 = nn.Linear(input_dim, hidden_dim // 2)
        hidden_dim = hidden_dim // 2
        self.linear2 = nn.Linear(hidden_dim, hidden_dim // 2)
        hidden_dim = hidden_dim // 2
        self.linear3 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.linear4 = nn.Linear( hidden_dim // 2, output_dim)

    def forward(self, x):
        out = self.linear1(x)
        out = F.leaky_relu(out,0.01)
        out = self.linear2(out)
        out = F.leaky_relu(out,0.01)
        out = self.linear3(out)
        out = F.leaky_relu(out,0.01)
        out = self.linear4(out)

        out = F.sigmoid(out)
        return out

    def predict(self, X, device='cpu'):
        X = torch.FloatTensor(np.array(X)).to(device)

        with torch.no_grad():
          y_pred = self.forward(X)

        return y_pred.numpy()


model = BinaryClassifier(7, 100, 1)
model
# Out:
# BinaryClassifier(
#   (linear1): Linear(in_features=7, out_features=50, bias=True)
#   (linear2): Linear(in_features=50, out_features=25, bias=True)
#   (linear3): Linear(in_features=25, out_features=12, bias=True)
#   (linear4): Linear(in_features=12, out_features=1, bias=True)
# )

# %%
from torchsummary import summary

summary(model, input_size=(7,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 50]             400
#             Linear-2                   [-1, 25]           1,275
#             Linear-3                   [-1, 12]             312
#             Linear-4                    [-1, 1]              13
# ================================================================
# Total params: 2,000
# Trainable params: 2,000
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %% [markdown]
# # Завдання 4
# Визначте функцію втрат та оптимізатор

# %%
loss_fn = nn.BCELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Завдання 5
# Натренуйте нейромережу. Візміть невелику кількість епох

# %%
# @title Функція для тренування
import time

def train(model, optimizer, loss_fn, train_dl, val_dl,
          metrics=None, metrics_name=None, epochs=20, device='cpu', task='regression'):
    '''
    Runs training loop for classification problems. Returns Keras-style
    per-epoch history of loss and accuracy over training and validation data.

    Parameters
    ----------
    model : nn.Module
        Neural network model
    optimizer : torch.optim.Optimizer
        Search space optimizer (e.g. Adam)
    loss_fn :
        Loss function (e.g. nn.CrossEntropyLoss())
    train_dl :
        Iterable dataloader for training data.
    val_dl :
        Iterable dataloader for validation data.
    metrics: list
        List of sklearn metrics functions to be calculated
    metrics_name: list
        List of matrics names
    epochs : int
        Number of epochs to run
    device : string
        Specifies 'cuda' or 'cpu'
    task : string
        type of problem. It can be regression, binary or multiclass

    Returns
    -------
    Dictionary
        Similar to Keras' fit(), the output dictionary contains per-epoch
        history of training loss, training accuracy, validation loss, and
        validation accuracy.
    '''

    print('train() called: model=%s, opt=%s(lr=%f), epochs=%d, device=%s\n' % \
          (type(model).__name__, type(optimizer).__name__,
           optimizer.param_groups[0]['lr'], epochs, device))

    metrics = metrics if metrics else []
    metrics_name = metrics_name if metrics_name else [metric.__name__ for metric in metrics]

    history = {} # Collects per-epoch loss and metrics like Keras' fit().
    history['loss'] = []
    history['val_loss'] = []
    for name in metrics_name:
        history[name] = []
        history[f'val_{name}'] = []

    start_time_train = time.time()

    for epoch in range(epochs):

        # --- TRAIN AND EVALUATE ON TRAINING SET -----------------------------
        start_time_epoch = time.time()

        model.train()
        history_train = {name: 0 for name in ['loss']+metrics_name}

        for batch in train_dl:
            x    = batch[0].to(device)
            y    = batch[1].to(device)
            y_pred = model(x)
            loss = loss_fn(y_pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            y_pred = y_pred.detach().numpy()
            y = y.detach().numpy()


            history_train['loss'] += loss.item() * x.size(0)
            for name, func in zip(metrics_name, metrics):
              try:
                  history_train[name] += func(y, y_pred) * x.size(0)
              except:
                  if task == 'binary': y_pred_ = y_pred.round()
                  elif task == 'multiclass': y_pred_ = y_pred.argmax(axis=-1)
                  history_train[name] += func(y, y_pred_) * x.size(0)

        for name in history_train:
            history_train[name] /= len(train_dl.dataset)


        # --- EVALUATE ON VALIDATION SET -------------------------------------
        model.eval()
        history_val = {'val_' + name: 0 for name in metrics_name+['loss']}

        with torch.no_grad():
            for batch in val_dl:
                x    = batch[0].to(device)
                y    = batch[1].to(device)
                y_pred = model(x)
                loss = loss_fn(y_pred, y)

                y_pred = y_pred.detach().numpy()
                y = y.detach().numpy()

                history_val['val_loss'] += loss.item() * x.size(0)
                for name, func in zip(metrics_name, metrics):
                    try:
                        history_val['val_'+name] += func(y, y_pred) * x.size(0)
                    except:
                        if task == 'binary': y_pred_ = y_pred.round()
                        elif task == 'multiclass': y_pred_ = y_pred.argmax(axis=-1)

                        history_val['val_'+name] += func(y, y_pred_) * x.size(0)

        for name in history_val:
            history_val[name] /= len(val_dl.dataset)

        # PRINTING RESULTS

        end_time_epoch = time.time()

        for name in history_train:
            history[name].append(history_train[name])
            history['val_'+name].append(history_val['val_'+name])

        total_time_epoch = end_time_epoch - start_time_epoch

        print(f'Epoch {epoch+1:4d} {total_time_epoch:4.0f}sec', end='\t')
        for name in history_train:
            print(f'{name}: {history[name][-1]:10.3g}', end='\t')
            print(f"val_{name}: {history['val_'+name][-1]:10.3g}", end='\t')
        print()

    # END OF TRAINING LOOP

    end_time_train       = time.time()
    total_time_train     = end_time_train - start_time_train
    print()
    print('Time total:     %5.2f sec' % (total_time_train))

    return history

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

history = train(model, optimizer, loss_fn, train_dl, test_dl,
                epochs=1000,
                metrics=[accuracy_score, roc_auc_score],
                task='binary')
# Out:
# train() called: model=BinaryClassifier, opt=Adam(lr=0.001000), epochs=1000, device=cpu
#
# Epoch    1    0sec	loss:      0.689	val_loss:      0.685	accuracy_score:      0.501	val_accuracy_score:      0.504	roc_auc_score:      0.897	val_roc_auc_score:      0.932
# Epoch    2    0sec	loss:      0.675	val_loss:      0.659	accuracy_score:      0.622	val_accuracy_score:      0.711	roc_auc_score:      0.948	val_roc_auc_score:      0.942
# Epoch    3    0sec	loss:       0.63	val_loss:       0.59	accuracy_score:      0.785	val_accuracy_score:      0.851	roc_auc_score:      0.945	val_roc_auc_score:      0.938
# Epoch    4    0sec	loss:      0.532	val_loss:      0.467	accuracy_score:      0.853	val_accuracy_score:      0.869	roc_auc_score:      0.946	val_roc_auc_score:      0.942
# Epoch    5    0sec	loss:       0.41	val_loss:      0.362	accuracy_score:      0.876	val_accuracy_score:      0.876	roc_auc_score:       0.95	val_roc_auc_score:      0.948
# Epoch    6    0sec	loss:      0.327	val_loss:      0.306	accuracy_score:      0.886	val_accuracy_score:      0.887	roc_auc_score:      0.955	val_roc_auc_score:      0.954
# Epoch    7    0sec	loss:      0.286	val_loss:      0.281	accuracy_score:      0.891	val_accuracy_score:      0.891	roc_auc_score:      0.958	val_roc_auc_score:      0.954
# Epoch    8    0sec	loss:      0.264	val_loss:      0.275	accuracy_score:      0.895	val_accuracy_score:      0.886	roc_auc_score:      0.961	val_roc_auc_score:      0.957
# Epoch    9    0sec	loss:      0.255	val_loss:      0.259	accuracy_score:      0.894	val_accuracy_score:      0.899	roc_auc_score:      0.964	val_roc_auc_score:       0.96
# Epoch   65    0sec	loss:      0.119	val_loss:      0.132	accuracy_score:       0.96	val_accuracy_score:      0.956	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   66    0sec	loss:      0.118	val_loss:      0.139	accuracy_score:      0.961	val_accuracy_score:      0.952	roc_auc_score:       0.99	val_roc_auc_score:      0.986
# Epoch   67    0sec	loss:      0.118	val_loss:      0.131	accuracy_score:       0.96	val_accuracy_score:      0.958	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   68    0sec	loss:      0.118	val_loss:      0.135	accuracy_score:      0.961	val_accuracy_score:      0.956	roc_auc_score:       0.99	val_roc_auc_score:      0.986
# Epoch   69    0sec	loss:      0.117	val_loss:      0.131	accuracy_score:      0.962	val_accuracy_score:      0.958	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   70    0sec	loss:      0.116	val_loss:      0.128	accuracy_score:      0.962	val_accuracy_score:      0.957	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   71    0sec	loss:      0.116	val_loss:      0.129	accuracy_score:       0.96	val_accuracy_score:      0.959	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   72    0sec	loss:      0.115	val_loss:      0.128	accuracy_score:      0.961	val_accuracy_score:      0.959	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   73    0sec	loss:      0.116	val_loss:      0.128	accuracy_score:       0.96	val_accuracy_score:      0.956	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   74    0sec	loss:      0.115	val_loss:      0.125	accuracy_score:      0.961	val_accuracy_score:       0.96	roc_auc_score:       0.99	val_roc_auc_score:      0.987
# Epoch   75    0sec	loss:      0.114	val_loss:      0.125	accuracy_score:      0.961	val_accuracy_score:       0.96	roc_auc_score:       0.99	val_roc_auc_score:      0.988
# Epoch   76    0sec	loss:      0.114	val_loss:      0.126	accuracy_score:      0.964	val_accuracy_score:      0.959	roc_auc_score:      0.991	val_roc_auc_score:      0.987
# Epoch   77    0sec	loss:      0.111	val_loss:      0.124	accuracy_score:      0.962	val_accuracy_score:      0.962	roc_auc_score:       0.99	val_roc_auc_score:      0.988
# Epoch   78    0sec	loss:       0.11	val_loss:      0.127	accuracy_score:      0.963	val_accuracy_score:      0.959	roc_auc_score:      0.991	val_roc_auc_score:      0.988
# Epoch   79    0sec	loss:      0.111	val_loss:      0.123	accuracy_score:      0.962	val_accuracy_score:      0.963	roc_auc_score:      0.991	val_roc_auc_score:      0.988
# Epoch   80    0sec	loss:       0.11	val_loss:      0.121	accuracy_score:      0.964	val_accuracy_score:      0.963	roc_auc_score:      0.991	val_roc_auc_score:      0.989
# Epoch   81    0sec	loss:      0.109	val_loss:      0.121	accuracy_score:      0.963	val_accuracy_score:      0.962	roc_auc_score:      0.991	val_roc_auc_score:      0.988
# Epoch   82    0sec	loss:      0.108	val_loss:      0.121	accuracy_score:      0.964	val_accuracy_score:      0.963	roc_auc_score:      0.991	val_roc_auc_score:      0.988
# Epoch   83    0sec	loss:      0.108	val_loss:      0.118	accuracy_score:      0.964	val_accuracy_score:      0.962	roc_auc_score:      0.991	val_roc_auc_score:      0.989
# Epoch  102    0sec	loss:     0.0953	val_loss:       0.11	accuracy_score:      0.969	val_accuracy_score:      0.966	roc_auc_score:      0.993	val_roc_auc_score:       0.99
# Epoch  103    0sec	loss:     0.0949	val_loss:      0.107	accuracy_score:       0.97	val_accuracy_score:      0.971	roc_auc_score:      0.993	val_roc_auc_score:       0.99
# Epoch  104    0sec	loss:     0.0938	val_loss:      0.109	accuracy_score:      0.971	val_accuracy_score:      0.967	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  105    0sec	loss:     0.0927	val_loss:      0.105	accuracy_score:      0.971	val_accuracy_score:      0.968	roc_auc_score:      0.992	val_roc_auc_score:       0.99
# Epoch  106    0sec	loss:     0.0919	val_loss:      0.106	accuracy_score:      0.971	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:       0.99
# Epoch  107    0sec	loss:      0.091	val_loss:      0.105	accuracy_score:      0.972	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  108    0sec	loss:     0.0919	val_loss:      0.103	accuracy_score:      0.971	val_accuracy_score:       0.97	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  109    0sec	loss:     0.0906	val_loss:      0.103	accuracy_score:      0.972	val_accuracy_score:       0.97	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  110    0sec	loss:     0.0916	val_loss:      0.107	accuracy_score:      0.972	val_accuracy_score:      0.965	roc_auc_score:      0.993	val_roc_auc_score:       0.99
# Epoch  111    0sec	loss:     0.0908	val_loss:      0.104	accuracy_score:      0.972	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  112    0sec	loss:     0.0909	val_loss:      0.101	accuracy_score:      0.971	val_accuracy_score:       0.97	roc_auc_score:      0.993	val_roc_auc_score:       0.99
# Epoch  113    0sec	loss:     0.0892	val_loss:      0.103	accuracy_score:      0.973	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:       0.99
# Epoch  114    0sec	loss:       0.09	val_loss:      0.103	accuracy_score:      0.973	val_accuracy_score:       0.97	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  115    0sec	loss:     0.0885	val_loss:      0.101	accuracy_score:      0.973	val_accuracy_score:       0.97	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  116    0sec	loss:     0.0877	val_loss:      0.102	accuracy_score:      0.974	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  117    0sec	loss:     0.0875	val_loss:        0.1	accuracy_score:      0.973	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  118    0sec	loss:     0.0872	val_loss:        0.1	accuracy_score:      0.974	val_accuracy_score:      0.969	roc_auc_score:      0.993	val_roc_auc_score:      0.991
# Epoch  119    0sec	loss:     0.0873	val_loss:     0.0994	accuracy_score:      0.974	val_accuracy_score:      0.971	roc_auc_score:      0.993	val_roc_auc_score:      0.991
roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  986    0sec	loss:     0.0273	val_loss:      0.108	accuracy_score:      0.992	val_accuracy_score:      0.981	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  987    0sec	loss:     0.0286	val_loss:      0.161	accuracy_score:      0.991	val_accuracy_score:       0.98	roc_auc_score:      0.999	val_roc_auc_score:      0.992
# Epoch  988    0sec	loss:     0.0258	val_loss:      0.109	accuracy_score:      0.992	val_accuracy_score:      0.981	roc_auc_score:          1	val_roc_auc_score:      0.991
# Epoch  989    0sec	loss:     0.0261	val_loss:      0.108	accuracy_score:      0.992	val_accuracy_score:      0.981	roc_auc_score:          1	val_roc_auc_score:      0.991
# Epoch  990    0sec	loss:     0.0253	val_loss:      0.108	accuracy_score:      0.992	val_accuracy_score:      0.979	roc_auc_score:          1	val_roc_auc_score:      0.991
# Epoch  991    0sec	loss:     0.0269	val_loss:      0.105	accuracy_score:      0.992	val_accuracy_score:      0.979	roc_auc_score:          1	val_roc_auc_score:      0.992
# Epoch  992    0sec	loss:     0.0282	val_loss:      0.112	accuracy_score:      0.991	val_accuracy_score:      0.981	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  993    0sec	loss:     0.0297	val_loss:      0.115	accuracy_score:       0.99	val_accuracy_score:      0.981	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  994    0sec	loss:     0.0286	val_loss:      0.109	accuracy_score:      0.991	val_accuracy_score:      0.981	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  995    0sec	loss:     0.0316	val_loss:      0.103	accuracy_score:       0.99	val_accuracy_score:      0.981	roc_auc_score:      0.999	val_roc_auc_score:      0.992
# Epoch  996    0sec	loss:     0.0284	val_loss:      0.111	accuracy_score:      0.992	val_accuracy_score:      0.978	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  997    0sec	loss:      0.027	val_loss:      0.176	accuracy_score:      0.992	val_accuracy_score:      0.971	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch  998    0sec	loss:     0.0276	val_loss:      0.112	accuracy_score:      0.991	val_accuracy_score:      0.981	roc_auc_score:          1	val_roc_auc_score:      0.991
# Epoch  999    0sec	loss:      0.028	val_loss:      0.112	accuracy_score:      0.991	val_accuracy_score:      0.979	roc_auc_score:      0.999	val_roc_auc_score:      0.991
# Epoch 1000    0sec	loss:     0.0252	val_loss:      0.109	accuracy_score:      0.993	val_accuracy_score:      0.978	roc_auc_score:          1	val_roc_auc_score:      0.992
#
# Time total:     279.85 sec

# %%
import matplotlib.pyplot as plt

def plot_metric(history, name):
  plt.title(f"Model results with {name}")
  plt.plot(history[name], label='train')
  plt.plot(history['val_'+name], label='val')
  plt.xlabel('Epoch')
  plt.ylabel(name)
  plt.legend()


plot_metric(history, 'loss')

# %%
plot_metric(history, 'accuracy_score')

# %%
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay

y_pred = model.predict(X_test)

ConfusionMatrixDisplay.from_predictions(y_test, y_pred.round())
plt.plot()

RocCurveDisplay.from_predictions(y_test, y_pred, pos_label=1)

# %% [markdown]
# # Завдання 6
# Збережіть нейромережу та зробіть прогноз

# %%
torch.save(model, 'model.pt')
load_model = torch.load('model.pt')

# %%
y_test.values[3]
# Out:
# 0

# %%
X_data = torch.FloatTensor(X_test.values[[3]])
X_data = X_data.to(device)

print(X_data)
print(X_data.shape)
# Out:
# tensor([[0.2851, 0.5765, 0.2482, 0.3430, 0.5679, 0.5586, 0.3057]])
# torch.Size([1, 7])

# %%
load_model(X_data).round().item()
# Out:
# 0.0
